# %%
import numpy as np

a=10
b=15
print("bit of a",bin(a))
print("bit of b",bin(b))

print("bitwise",np.bitwise_and(a,b))
print("bitwise",np.bitwise_or(a,b))
print(np.invert(a))
print(np.right_shift(20,3))
print(np.left_shift(20,3))

#bitwise need np
# Out:
# bit of a 0b1010
# bit of b 0b1111
# bitwise 10
# bitwise 15
# -11
# 2
# 160
