# %%
import matplotlib.pyplot as plt
import numpy as np

populationage=[10,25,10,21,33,14,19,27,35,40]
bins=[0,10,20,30,40,50]
plt.hist(populationage,bins,histtype='bar',rwidth=0.8)
# Out:
# (array([0., 4., 3., 2., 1.]),
#  array([ 0., 10., 20., 30., 40., 50.]),
#  <BarContainer object of 5 artists>)

# %%
mu=50 
sigma=15 
x=np.random.normal(mu,sigma,1000) 
plt.hist(x, bins=30, density=True, alpha=0.6, color='g')
# Out:
# (array([0.00027251, 0.        , 0.        , 0.        , 0.00054502,
#         0.00081754, 0.00190758, 0.00272512, 0.00517773, 0.00572275,
#         0.00872039, 0.01226304, 0.01607821, 0.01607821, 0.02779623,
#         0.0294313 , 0.02289101, 0.02588864, 0.02071092, 0.02016589,
#         0.0204384 , 0.01335309, 0.00817536, 0.00654029, 0.00327014,
#         0.0021801 , 0.00081754, 0.        , 0.00027251, 0.00027251]),
#  array([-10.53326785,  -6.86370538,  -3.19414291,   0.47541955,
#           4.14498202,   7.81454449,  11.48410695,  15.15366942,
#          18.82323189,  22.49279435,  26.16235682,  29.83191929,
#          33.50148175,  37.17104422,  40.84060668,  44.51016915,
#          48.17973162,  51.84929408,  55.51885655,  59.18841902,
#          62.85798148,  66.52754395,  70.19710642,  73.86666888,
#          77.53623135,  81.20579382,  84.87535628,  88.54491875,
#          92.21448122,  95.88404368,  99.55360615]),
#  <BarContainer object of 30 artists>)
