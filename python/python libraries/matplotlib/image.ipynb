# %%
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import image
from matplotlib import style

from PIL import Image  
fname = "C:/Users/Jay Khatwani/OneDrive/Desktop/hnb/python/python libraries/matplotlib/bridge.jpeg"
image = Image.open(fname).convert("L")
plt.imshow(image, cmap="gray")

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import style

from PIL import Image
fname = "C:/Users/Jay Khatwani/OneDrive/Desktop/hnb/python/python libraries/matplotlib/bridge.jpeg"
image = Image.open(fname)
plt.imshow(image)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import style

from PIL import Image
fname = "C:/Users/Jay Khatwani/OneDrive/Desktop/hnb/python/python libraries/matplotlib/bridge.jpeg"
image = Image.open(fname).convert("L")
plt.imshow(image, cmap="Reds_r")

# %%
names=["jay","krish","kartik"]
marks=[5,10,15]

plt.subplot(131)
plt.bar(names,marks)
plt.subplot(132)
plt.plot(names,marks)
plt.subplot(133)
plt.scatter(names,marks)
