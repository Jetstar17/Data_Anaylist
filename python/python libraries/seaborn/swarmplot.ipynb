# %%
import seaborn as sns
sns.set(style="darkgrid")
f=sns.load_dataset("fmri")
sns.swarmplot(x="timepoint",y="signal",data=f)
# Out:
# c:\Users\Jay Khatwani\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 69.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Jay Khatwani\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 67.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Jay Khatwani\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Jay Khatwani\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 46.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
