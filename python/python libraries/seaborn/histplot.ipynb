# %%
import seaborn as sns
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",element="poly")    
#here poly so sepration of female and male is visible in polygon
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="time",hue="sex",shrink=0.7)
# Out:
# <Axes: xlabel='time', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",element="step")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",element="step",fill=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",element="step",log_scale=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
t=sns.load_dataset("tips")
sns.histplot(data=t,bins=20,x="total_bill",hue="sex",element="step",fill=False,log_scale=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns

tips=sns.load_dataset("tips")

sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, x="day", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", stat="probability")
# Out:
# <Axes: xlabel='total_bill', ylabel='Probability'>

# %%
penguins=sns.load_dataset("penguins")
sns.histplot(data=penguins, x="bill_length_mm", hue="island")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
iris=sns.load_dataset("iris")
sns.histplot(data=iris, x="petal_length", y="petal_width")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import seaborn as sns
#       2 #iris=sns.load_dataset("iris")
# ----> 3 sns.histplot(data=tips, x="petal_length", y="petal_width")
#
# NameError: name 'tips' is not defined

# %%
planets=sns.load_dataset("planets")
sns.histplot(data=planets, x="distance", log_scale=True)
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", cumulative=True, fill=False, element="step")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>
