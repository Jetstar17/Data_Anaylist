# %%
import seaborn as sns

f=sns.load_dataset("fmri")
sns.violinplot(x="timepoint",y="signal",data=f)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.violinplot(x="timepoint",y="signal",data=f,hue="region")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.set(style="whitegrid")
s=sns.load_dataset("tips")
sns.violinplot(x="day",y="tip",data=s)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
