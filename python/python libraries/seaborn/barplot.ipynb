# %%
import seaborn as sns
t=sns.load_dataset("titanic")

sns.barplot(x="class",y="fare",data=t)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="class",y="fare",hue="sex",data=t)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="fare",y="class",hue="sex",data=t)
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
sns.barplot(x="class",y="fare",hue="sex",data=t,order=["Third","Second","First"])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="class",y="fare",data=t,color="salmon")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="class",y="fare",hue="sex",data=t,ci=None)
# Out:
# C:\Users\Jay Khatwani\AppData\Local\Temp\ipykernel_8872\4228156441.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="class",y="fare",hue="sex",data=t,ci=None)
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="class",y="fare",data=t,palette="pastel",hue="sex")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import matplotlib.pylab as plt
import numpy as np
from numpy import median
sns.barplot(x="class",y="fare",hue="sex",data=t,estimator=median)  #median values
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x="class",y="fare",hue="sex",data=t,saturation=0.1)  #sat for mat fin
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
sns.barplot(x="class",y="fare",hue="sex",data=t,facecolor=(1, 1, 1, 0),  # Fully transparent (R, G, B, Alpha)
    errcolor=".2",           # Color of the error bars
    edgecolor="blue", 
    linewidth=3)
p`   `
# Out:
# C:\Users\Jay Khatwani\AppData\Local\Temp\ipykernel_5748\4098520302.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.2'}` instead.
#
#   sns.barplot(x="class",y="fare",hue="sex",data=t,facecolor=(1, 1, 1, 0),  # Fully transparent (R, G, B, Alpha)
# <Axes: xlabel='class', ylabel='fare'>
