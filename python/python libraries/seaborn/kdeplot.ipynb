# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.random.randn(200)


sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
x=np.random.randn(200)


sns.kdeplot(x, shade=True)
# Out:
# C:\Users\Jay Khatwani\AppData\Local\Temp\ipykernel_10312\1013777918.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x, shade=True)
# <Axes: ylabel='Density'>

# %%
x=np.random.randn(200)


sns.kdeplot(x,color="green",shade=True)  #if false only line color
# Out:
# C:\Users\Jay Khatwani\AppData\Local\Temp\ipykernel_10312\3919095036.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,color="green",shade=True)
# <Axes: ylabel='Density'>
