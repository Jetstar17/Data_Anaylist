# %%
import  seaborn as sns
t=sns.load_dataset("tips")
sns.stripplot(x="day",y="total_bill",data=t)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="sex",y="total_bill",data=t,hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
